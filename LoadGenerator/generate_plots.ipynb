# %%
# !pip install matplotlib numpy
# Out:
# ...
#   Using cached numpy-2.3.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 kB 2.9 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 9.8 MB/s eta 0:00:00:00:0100:01
# Using cached numpy-2.3.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.6/362.6 kB 6.4 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 10.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 9.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 10.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.9/113.9 kB 5.0 MB/s eta 0:00:00
# ...

# %%
# !python3 plot_results.py "./CL_outputs/read/read_*.txt" --output-dir graphs/read/
# Out:
# Found 5 log files to process...
#   Parsing: ./CL_outputs/read/read_16thread.txt
#   Parsing: ./CL_outputs/read/read_1thread.txt
#   Parsing: ./CL_outputs/read/read_2thread.txt
#   Parsing: ./CL_outputs/read/read_4thread.txt
#   Parsing: ./CL_outputs/read/read_8thread.txt
#
# Processed 5 test results across 1 workload(s)
#
# Generating plots...
# ✓ Saved: graphs/read/throughput_vs_load.png
# ✓ Saved: graphs/read/mean_latency_vs_load.png
# ✓ Saved: graphs/read/median_latency_vs_load.png
# ✓ Saved: graphs/read/p95_latency_vs_load.png
# ✓ Saved: graphs/read/p99_latency_vs_load.png
# ✓ Saved: graphs/read/combined_latency_vs_load.png
#
# ...
# LOAD TEST RESULTS SUMMARY
# ...
#
# READ Workload:
# --------------------------------------------------------------------------------
# Load       Throughput      Mean Lat     P95 Lat      P99 Lat
#            (req/s)         (ms)         (ms)         (ms)
# --------------------------------------------------------------------------------
# ...

# %%
# !python3 plot_resource_utilization.py "./profiling/monitoring_logs/read/summary_read_*.txt" --output-dir graphs/read/
# Out:
# ...
# RESOURCE UTILIZATION PLOTTER
# ...
#
# Found 5 summary files
#   Parsing: ./profiling/monitoring_logs/read/summary_read_16thread.txt
#   Parsing: ./profiling/monitoring_logs/read/summary_read_1thread.txt
#   Parsing: ./profiling/monitoring_logs/read/summary_read_2thread.txt
#   Parsing: ./profiling/monitoring_logs/read/summary_read_4thread.txt
#   Parsing: ./profiling/monitoring_logs/read/summary_read_8thread.txt
#
# Processed 5 data points
# Workloads found: Read
#
# ...
# GENERATING RESOURCE UTILIZATION GRAPHS
# ...
#
# ✓ Saved: graphs/read/cpu_utilization_vs_load.png
# ✓ Saved: graphs/read/disk_utilization_vs_load.png
# ✓ Saved: graphs/read/io_await_vs_load.png
#
# ...
# GENERATING BOTTLENECK ANALYSIS DASHBOARD
# ...
#
# ✓ Saved: graphs/read/bottleneck_dashboard.png
#
# ...
# RESOURCE UTILIZATION SUMMARY
# ...
#
# Read Workload:
# ----------------------------------------------------------------------
# Load       CPU %      Disk %     I/O Wait     Memory
#                                  (ms)         (MB)
# ...

# %%
# !python3 plot_results_universal.py "./CL_outputs/write/write_*.txt" --output-dir graphs/write/
# Out:
# ...
# UNIVERSAL LOAD TEST RESULTS PLOTTER
# ...
#
# Found 6 log files
#   Parsing: ./CL_outputs/write/write_16thread.txt
#   Parsing: ./CL_outputs/write/write_1thread.txt
#   Parsing: ./CL_outputs/write/write_2thread.txt
#   Parsing: ./CL_outputs/write/write_32thread.txt
#   Parsing: ./CL_outputs/write/write_4thread.txt
#   Parsing: ./CL_outputs/write/write_8thread.txt
#
# Processed 6 results across 1 workload(s)
# Workloads: Write
#
# ...
# GENERATING GRAPHS
# ...
#
# ✓ Saved: graphs/write/throughput_vs_load.png
# ✓ Saved: graphs/write/mean_latency_vs_load.png
# ✓ Saved: graphs/write/median_latency_vs_load.png
# ✓ Saved: graphs/write/p95_latency_vs_load.png
# ✓ Saved: graphs/write/p99_latency_vs_load.png
#
# ...
# LOAD TEST RESULTS SUMMARY
# ...
#
# Write Workload:
# ----------------------------------------------------------------------
# Load       Throughput      Mean Lat     P95 Lat
#            (req/s)         (ms)         (ms)
# ----------------------------------------------------------------------
# ...

# %%
# !python3 plot_resource_utilization.py "./profiling/monitoring_logs/write/summary_write_*.txt" --output-dir graphs/write/
# Out:
# ...
# RESOURCE UTILIZATION PLOTTER
# ...
#
# Found 6 summary files
#   Parsing: ./profiling/monitoring_logs/write/summary_write_16thread.txt
#   Parsing: ./profiling/monitoring_logs/write/summary_write_1thread.txt
#   Parsing: ./profiling/monitoring_logs/write/summary_write_2thread.txt
#   Parsing: ./profiling/monitoring_logs/write/summary_write_32thread.txt
#   Parsing: ./profiling/monitoring_logs/write/summary_write_4thread.txt
#   Parsing: ./profiling/monitoring_logs/write/summary_write_8thread.txt
#
# Processed 6 data points
# Workloads found: Write
#
# ...
# GENERATING RESOURCE UTILIZATION GRAPHS
# ...
#
# ✓ Saved: graphs/write/cpu_utilization_vs_load.png
# ✓ Saved: graphs/write/disk_utilization_vs_load.png
# ✓ Saved: graphs/write/io_await_vs_load.png
#
# ...
# GENERATING BOTTLENECK ANALYSIS DASHBOARD
# ...
#
# ✓ Saved: graphs/write/bottleneck_dashboard.png
#
# ...
# RESOURCE UTILIZATION SUMMARY
# ...
#
# Write Workload:
# ----------------------------------------------------------------------
# ...
